# %%
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import sys
sys.path.insert(0, "../src")   # so you can import from src/ or project root

from database import engine

df = pd.read_sql("SELECT * FROM world_population", con=engine)
df.head()   # renders as a table inline
# Out:
#          country  population_2026  yearly_change  net_change  density_per_km2  \
# 0          India       1476625576           0.87  12760051.0              497
# 1          China       1412914089          -0.22  -3182005.0              150
# 2  United States        349035494           0.51   1759687.0               38
# 3      Indonesia        287886782           0.76   2165546.0              159
# 4       Pakistan        259299791           1.60   4080237.0              336
#
#    land_area_km2  migrants_net  fertility_rate  median_age  \
# 0        2973190     -440456.0            1.93        29.2
# 1        9388211     -232107.0            1.03        40.6
# 2        9147420     1177848.0            1.63        38.7
# 3        1811570      -39472.0            2.08        30.7
# 4         770880    -1144738.0            3.44        20.8
#
#    urban_population_pct  world_share_pct
# 0                  37.6            17.79
# 1                  68.7            17.02
# ...

# %%
df["population_2026"].plot(kind="bar")   # renders plot inline
# Out:
# <Axes: >
